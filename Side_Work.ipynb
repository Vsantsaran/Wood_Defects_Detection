# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv
import os

# %%
'''
images_folder_path = 'Images9'
new_path = 'Images9 JPG'
img_ext = '.jpg'
if not os.path.exists(new_path):
    os.makedirs(new_path)

images_dir = os.listdir(images_folder_path)

for i, image in enumerate(images_dir):
    img_path = os.path.join(images_folder_path, image)
    img = cv.imread(img_path)
    filename, ext = os.path.splitext(image)
    new_filename = f"{filename}{img_ext}"
    full_path = os.path.join(new_path, new_filename)
    cv.imwrite(full_path, img)
    print(f'Image {i} saved as: {new_filename}')
'''
# Out:
# '\nimages_folder_path = \'Images9\'\nnew_path = \'Images9 JPG\'\nimg_ext = \'.jpg\'\nif not os.path.exists(new_path):\n    os.makedirs(new_path)\n\nimages_dir = os.listdir(images_folder_path)\n\nfor i, image in enumerate(images_dir):\n    img_path = os.path.join(images_folder_path, image)\n    img = cv.imread(img_path)\n    filename, ext = os.path.splitext(image)\n    new_filename = f"{filename}{img_ext}"\n    full_path = os.path.join(new_path, new_filename)\n    cv.imwrite(full_path, img)\n    print(f\'Image {i} saved as: {new_filename}\')\n'

# %% [markdown]
# ## Monitoring the results and metrics on the fly

# %% [markdown]
# ### Results (.bmp images)

# %%
res_path_train3 = 'runs/detect/train3/results.csv'
res_df = pd.read_csv(res_path_train3)
res_df
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      1                2.9769                4.2905
# 1                      2                2.4019                3.4804
# 2                      3                2.1316                3.0924
# 3                      4                1.9314                2.8117
# 4                      5                1.8731                2.7995
# 5                      6                1.7975                2.6572
# 6                      7                1.7079                2.5624
# 7                      8                1.6295                2.3937
# 8                      9                1.5778                2.3682
# 9                     10                1.5107                2.2582
# 10                    11                1.4580                2.5678
# 11                    12                1.3162                2.2317
# 12                    13                1.2745                2.0932
# ...

# %% [markdown]
# ### Results (.jpg images)

# %%
res_path_train4 = 'runs/detect/train4/results.csv'
res_df_1 = pd.read_csv(res_path_train4)
res_df_1
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      1                2.9877                4.3442
# 1                      2                2.3753                3.4930
# 2                      3                2.0990                3.1046
# 3                      4                1.9112                2.8482
# 4                      5                1.8544                2.8091
# 5                      6                1.7927                2.6675
# 6                      7                1.7001                2.5771
# 7                      8                1.6157                2.4408
# 8                      9                1.5968                2.4296
# 9                     10                1.5482                2.3222
# 10                    11                1.4679                2.7043
# 11                    12                1.3636                2.3535
# 12                    13                1.3159                2.2429
# ...

# %% [markdown]
# ## Results:

# %% [markdown]
# ### CMD (train5)

# %%
res_path_train5 = 'runs/detect/train5/results.csv'
res_df_2 = pd.read_csv(res_path_train5)
res_df_2
# Out:
#                    epoch        train/box_loss        train/cls_loss  \
# 0                      1                2.3457               4.04820
# 1                      2                1.9889               2.02780
# 2                      3                1.9955               1.76920
# 3                      4                1.9852               1.69510
# 4                      5                1.9261               1.57230
# 5                      6                1.8895               1.49970
# 6                      7                1.8618               1.46730
# 7                      8                1.8616               1.41700
# 8                      9                1.8222               1.45770
# 9                     10                1.8111               1.33760
# 10                    11                1.8546               1.30080
# 11                    12                1.7997               1.28100
# 12                    13                1.7370               1.26390
# ...

# %% [markdown]
# ## <u>Observations</u> -
# <b>
# 1. mAP score for bmp images is higher than that of jpg. <br>
# <i> Reason: Every bmp image is around 8-9 MB big and every jpg image is in KBs. So the carity we get in bmp images is of higher quality, which is compensated by low quality and small size in jpg images. </i> <br>
# </b>

# %% [markdown]
# ## Changing the class name to a numerical value in annotations

# %% [markdown]
# ### Renaming all 20276 annot files of dataset4:
# #### from 99100003_anno to 99100003

# %%
path_annot  = 'Bouding Boxes'
files = os.listdir(path_annot)
files
# Out:
# ['100000000.txt',
#  '100000001.txt',
#  '100000002.txt',
#  '100000003.txt',
#  '100000004.txt',
#  '100000005.txt',
#  '100000006.txt',
#  '100000007.txt',
#  '100000008.txt',
#  '100000009.txt',
#  '100000010.txt',
#  '100000011.txt',
#  '100000012.txt',
#  '100000013.txt',
#  '100000014.txt',
#  '100000015.txt',
#  '100000016.txt',
#  '100000017.txt',
#  '100000018.txt',
#  '100000019.txt',
#  '100000020.txt',
#  '100000021.txt',
#  '100000022.txt',
#  '100000023.txt',
#  '100000024.txt',
#  '100000032.txt',
#  '100000033.txt',
#  '100000034.txt',
#  '100000035.txt',
#  '100000036.txt',
#  '100000037.txt',
#  '100000038.txt',
#  '100000039.txt',
#  '100000040.txt',
#  '100000041.txt',
#  '100000042.txt',
#  '100000043.txt',
#  '100000044.txt',
#  '100000045.txt',
#  '100000046.txt',
#  '100000047.txt',
#  '100000048.txt',
#  '100000049.txt',
#  '100000050.txt',
#  '100000051.txt',
#  '100000052.txt',
#  '100000053.txt',
#  '100000054.txt',
#  '100000055.txt',
#  '100000056.txt',
# ...

# %%
for filename in files:
    #filename = files[0]
    file_path = os.path.join(path_annot, filename)
    splitted_filename = filename.split('_')
    new_filename = splitted_filename[0] + '.txt'
    new_path = os.path.join(path_annot, new_filename)
    os.rename(file_path, new_path)

# %%
count = 0
for filename in files:
    file_path = os.path.join(path_annot, filename)
    with open(file_path, 'r') as file:
        for line in file.readlines():
            content = line.split()
            class_name = content[0]
            #print(class_name)
            if class_name == 'overgrown':
                count += 1
count
# Out:
# 10

# %%
print(os.getcwd())
new_annot = 'new_annots'
os.listdir()
# Out:
# D:\sant_saran\Summer Training - I Year
# ['.ipynb_checkpoints',
#  '114600011.jpg',
#  'Bonafide Certificate.jpeg',
#  'Bouding Boxes',
#  'Bouding_Boxes.zip',
#  'Datasets',
#  'Final Project data',
#  'Imp links.txt',
#  'Imp points.txt',
#  'new_annots',
#  'Presentation',
#  'Presentation.pptx',
#  'Project Presentation.pptx',
#  'runs',
#  'Semantic Map Specification.txt',
#  'Side Work.ipynb',
#  'Woods_2.ipynb',
#  'Wood_Defects_Detection.ipynb',
#  'Work_done - Week 1.txt',
#  'Work_done - Week 2.txt',
#  'Work_done - Week 3.txt',
#  'Work_done - Week 4.txt',
#  '~$Presentation.pptx',
#  '~$Project Presentation.pptx']

# %%
# !mkdir new_annots
len(files), path_annot
# Out:
# (20276, 'Bouding Boxes')

# %%
maps = {'Live_Knot' : '0',
        'Dead_Knot' : '1', 
        'Knot_missing' : '2', 
        'knot_with_crack' : '3', 
        'Crack' : '4', 
        'Quartzity' : '5', 
        'resin' : '6', 
        'Marrow' : '7', 
        'Blue_Stain' : '8', 
        'overgrown' : '9'}

# %%
from pathlib import Path
for filename in files:
    file_path = os.path.join(path_annot, filename)
    # if os.path.getsize(file_path) == 0:
    #     with open(file_path, 'w') as new_file:
    #         new_file.write('')
    #         # os.mknod(file_path)
    #         # file_path = Path(file_path)
    #         # file_path.touch()
    #     continue
    with open(file_path, 'r') as file:
        contents = file.read()
    # replace all the defects' names with their corrosponding numerical value
    new_contents = contents.replace('Live_Knot', '0')
    new_contents = new_contents.replace('Dead_Knot', '1')
    new_contents = new_contents.replace('Knot_missing', '2')
    new_contents = new_contents.replace('knot_with_crack', '3')
    new_contents = new_contents.replace('Crack', '4')
    new_contents = new_contents.replace('Quartzity', '5')
    new_contents = new_contents.replace('resin', '6')
    new_contents = new_contents.replace('Marrow', '7')
    new_contents = new_contents.replace('Blue_Stain', '8')
    new_contents = new_contents.replace('overgrown', '9')

    with open(file_path, 'w') as new_file:
        new_file.write(new_contents)
    
        # for line in file.readlines():
        #     content = line.split()
        #     class_name = content[0]
        #     if class_name == 'Live_Knot':
        #         num_class_name = 0
        #     elif class_name == 'Dead_Knot':
        #          num_class_name = 1
        #     elif class_name == 'Knot_missing':
        #          num_class_name = 2
        #     elif class_name == 'knot_with_crack':
        #          num_class_name = 3
        #     elif class_name == 'Crack':
        #          num_class_name = 4
        #     elif class_name == 'Quartzity':
        #          num_class_name = 5
        #     elif class_name == 'resin':
        #          num_class_name = 6
        #     elif class_name == 'Marrow':
        #          num_class_name = 7
        #     elif class_name == 'Blue_Stain':
        #          num_class_name = 8
        #     elif class_name == 'overgrown':
        #          num_class_name = 9
        #     new_file_name = filename
        #     new_file_path = os.path.join(new_annot, filename)
        #     new_content = f'{num_class_name}\t{content[1]}\t{content[2]}\t{content[3]}\t{content[4]}\n'
        #     with open(new_file_path, 'a+') as new_file:
        #         new_file.write(new_content)

# %% [markdown]
# ## Confirming whether all the changed values are correct

# %%
count = 0
for filename in files:
    file_path = os.path.join(path_annot, filename)
    with open(file_path, 'r') as file:
        for line in file.readlines():
            content = line.split()
            class_name = content[0]
            #print(class_name)
            if class_name == '0':
                count += 1
count
# Out:
# 21224

# %%
maps
# Out:
# {'Live_Knot': '0',
#  'Dead_Knot': '1',
#  'Knot_missing': '2',
#  'knot_with_crack': '3',
#  'Crack': '4',
#  'Quartzity': '5',
#  'resin': '6',
#  'Marrow': '7',
#  'Blue_Stain': '8',
#  'overgrown': '9'}

# %% [markdown]
# #### Live_Knot - 21,224
# #### Dead_Knot - 11,985
# #### Knot_missing - 503
# #### knot_with_crack - 2,276
# #### Crack - 2,169
# #### Quartzity - 1,075
# #### resin - 3,455
# #### Marrow - 1,181
# #### Blue_Stain - 96
# #### overgrown - 10
# #### total - 43,974

# %% [markdown]
# ### Confirmed - all the labels (defects' names) have been successfully changed to their numerical values

# %% [markdown]
# ### How many instances of each detfect are there

# %%
folder_path = 'Datasets_list/Dataset1/Bounding_Boxes_YOLO_Format_1'
files = os.listdir(folder_path)
len(files)
# Out:
# 4000

# %%
count = 0
for filename in files:
    file_path = os.path.join(folder_path, filename)
    with open(file_path, 'r') as file:
        for line in file.readlines():
            content = line.split()
            class_name = content[0]
            #print(class_name)
            if class_name == '7':
                count += 1
count
# Out:
# 517

# %% [raw]
# Quartzity: 171
# Live-Knot: 4070
# Mrrow: 206
# resin:650
# dead-knot: 2934
# knot_with_crack: 542
# Knot_missing:121
# Crack: 517

# %%
map_2 = {
    "Quartzity": 171, 
    "Live-Knot": 4070, 
    "Mrrow": 206, 
    "resin":650, 
    "dead-knot": 2934, 
    "knot_with_crack": 542, 
    "Knot_missing":121, 
    "Crack": 517}
map_df = pd.DataFrame(list(map_2.items()), columns=['Defects', 'Counts'])
map_df
# Out:
#            Defects  Counts
# 0        Quartzity     171
# 1        Live-Knot    4070
# 2            Mrrow     206
# 3            resin     650
# 4        dead-knot    2934
# 5  knot_with_crack     542
# 6     Knot_missing     121
# 7            Crack     517

# %%
plt.figure(figsize=(10, 4))
# plt.bar(map_df.Defects, map_df.Counts, label='Wood Defects and their count')
plt.bar(map_2.keys(), map_2.values(), label='Wood Defects and their count')
plt.xlabel('Defects')
plt.ylabel('Counts')
plt.title('Wood Defects Count')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 5))
bars = plt.bar(map_2.keys(), map_2.values(), label='Wood Defects and their count')

# Annotate each bar with its value
for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,  # x position
        yval,                            # y position
        int(yval),                        # text value
        ha='center',                      # horizontal alignment
        va='bottom'                       # vertical alignment
    )

plt.xlabel('Defect')
plt.ylabel('Count')
plt.title('Wood Defects Count')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import requests
from pathlib import Path

path = 'https://raw.githubusercontent.com/ultralytics/ultralytics/1e5702a5b5a05809bfcb873a556bbcb8e49bbb05/ultralytics/yolo/utils/loss.py'
if Path(path).is_file():
    print("loss.py already exists, skipping download")
else:
    print("Downloading loss.py")
    request = requests.get(path)
    with open('loss.py', 'wb') as f:
        f.write(request.content)

# %%
# !nvidia-smi
# Out:
# Thu Feb 20 16:02:09 2025
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.82.01    Driver Version: 470.82.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   36C    P0    74W / 300W |  14974MiB / 32510MiB |     14%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import time
import ipyparallel as ipp

task_durations = [1] * 25
# request a cluster
with ipp.Cluster() as rc:
    # get a view on the cluster
    view = rc.load_balanced_view()
    # submit the tasks
    asyncresult = view.map_async(time.sleep, task_durations)
    # wait interactively for results
    asyncresult.wait_interactive()
    # retrieve actual results
    result = asyncresult.get()
# at this point, the cluster processes have been shutdown
# Out:
# Starting 80 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
# ...
# sleep:   0%|          | 0/25 [00:00<?, ?tasks/s]
# Stopping engine(s): 1740047539
# ...

# %%
import os

folder_path = "Dataset1/test/labels"
num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])

print(f"Number of files: {num_files}")
# Out:
# Number of files: 50

# %%
# 3600 350 50
